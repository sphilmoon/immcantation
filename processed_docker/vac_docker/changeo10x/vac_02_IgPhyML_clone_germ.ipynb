# %%
library(alakazam)
library(igraph)

db_clone = readIgphyml("vac_clone_igphyml-pass.tab")

# Plot largest lineage tree
plot(db_clone$trees[[1]],layout=layout_as_tree)

# Show HLP10 parameters
print(t(db_clone$param[1,]))
CLONE         =    "REPERTOIRE"
NSEQ          =   "4"
NSITE         =  "107"
TREE_LENGTH   = "0.286"
LHOOD         =  "-290.7928"
KAPPA_MLE     =  "2.266"
OMEGA_FWR_MLE = "0.5284"
OMEGA_CDR_MLE = "2.3324"
WRC_2_MLE     = "4.8019"
GYW_0_MLE     =   "3.4464"
WA_1_MLE      =  "5.972"
TW_0_MLE      =  "0.8131"
SYC_2_MLE     =  "-0.99"
GRS_0_MLE     =  "0.2583"
# Out:
#               1
# clone         "REPERTOIRE"
# nseq          "5932"
# nsite         "119.9774"
# tree_length   "0.003"
# lhood         "-91148.58"
# kappa_mle     "1.8179"
# omega_fwr_mle "0.7235"
# omega_cdr_mle "1.0396"
# wrc_2_mle     "0.6435"
# gyw_0_mle     "1.8125"
# wa_1_mle      "1.0172"
# tw_0_mle      "0.2868"
# syc_2_mle     "-0.8657"
# grs_0_mle     "-0.9658"
# Plot with title “”

# %%
library(alakazam)
library(ape)

db_clone = readIgphyml("vac_clone_igphyml-pass.tab", format="phylo")

# Plot largest lineage tree
plot(ladderize(db_clone$trees[[1]]),cex=0.7,no.margin=TRUE)
# Out:
# plot without title

# %%
library(alakazam)
library(igraph)

db_germ = readIgphyml("vac_germline_igphyml-pass.tab")

# Plot largest lineage tree
plot(db_germ$trees[[1]],layout=layout_as_tree)

# Show HLP10 parameters
print(t(db_germ$param[1,]))
CLONE         =    "REPERTOIRE"
NSEQ          =   "4"
NSITE         =  "107"
TREE_LENGTH   = "0.286"
LHOOD         =  "-290.7928"
KAPPA_MLE     =  "2.266"
OMEGA_FWR_MLE = "0.5284"
OMEGA_CDR_MLE = "2.3324"
WRC_2_MLE     = "4.8019"
GYW_0_MLE     =   "3.4464"
WA_1_MLE      =  "5.972"
TW_0_MLE      =  "0.8131"
SYC_2_MLE     =  "-0.99"
GRS_0_MLE     =  "0.2583"
# Out:
#               1
# clone         "REPERTOIRE"
# nseq          "5932"
# nsite         "119.972"
# tree_length   "0.003"
# lhood         "-91002.74"
# kappa_mle     "1.8531"
# omega_fwr_mle "0.7282"
# omega_cdr_mle "1.0533"
# wrc_2_mle     "0.5971"
# gyw_0_mle     "1.7997"
# wa_1_mle      "0.9849"
# tw_0_mle      "0.288"
# syc_2_mle     "-0.8626"
# grs_0_mle     "-0.9654"
# Plot with title “”

# %%
library(alakazam)
library(ape)

db_germ = readIgphyml("vac_germline_igphyml-pass.tab", format="phylo")

# Plot largest lineage tree
plot(ladderize(db_germ$trees[[1]]),cex=0.7,no.margin=TRUE)
# Out:
# plot without title
