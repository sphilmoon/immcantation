# %%
library(ggplot2)
library(tidyr)
library(dplyr)
library(reshape2)
# Out:
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths

# %%
# manual color codes
sample_colors <- c("Unprotected"="deeppink3", "Vaccinated.only"="steelblue2", "Control"="slategrey")

df <- read.csv("vloupe-paired-isotype.csv")
head(df)

df <- melt(df ,  id.vars = 'paired_isotype', variable.name = 'series')

#create line plot for each column in data frame
ggplot(df, aes(paired_isotype, value)) + theme_bw() + 
        geom_point(aes(colour = series, size=4, alpha=0.9)) + 
        scale_color_manual(values=sample_colors) + 
        theme(axis.text.x=element_text(angle=45, hjust=1, vjust=1)) +
        ylab("Isotype frequency") + xlab("Paired chains") +
        ggtitle("Paired isotype") +
        theme(legend.position="none")
# Out:
#   paired_isotype Control     Vaccinated.only Unprotected
# 1 IGK + IGHA     0.002550429 0.01204416      0.01683502
# 2 IGK + IGHD     0.207280315 0.12211442      0.20763187
# 3 IGK + IGHE     0.000000000 0.00000000      0.00000000
# 4 IGK + IGHG     0.005796429 0.01003680      0.13692480
# 5 IGK + IGHM     0.725249246 0.77484108      0.58922559
# 6 IGL + IGHA     0.000231857 0.00133824      0.00000000
# plot without title
