# %%
# Load ggplot2
library(ggplot2)

# manual color codes
sample_colors <- c("Protected"="seagreen", "Unprotected"="deeppink3", "Vaccinated-only"="steelblue2", "Control"="slategrey")

# Create data
data <- data.frame(
  name=c("Protected","Unprotected","Vaccinated-only","Control") ,  
  value=c(3009,1026,3688,5609)
  )

# Barplot
# ggplot(data, aes(x=name, y=value)) + 
#   geom_bar(stat = "identity")

# Plot V gene usage in the IGHV1 family by sample
g1 <- ggplot(data, aes(x=name, y=value)) +
    theme_bw() +
    theme(axis.text.x=element_text(face="bold", size=14),
         axis.text.y=element_text(face="bold", size=14),
         axis.title=element_text(size=18)) +
    ylab("Estimated number of cells") +
    xlab("") + 
    geom_col(stat = "identity", fill=sample_colors)

g1 + scale_x_discrete(limits = c("Protected","Unprotected","Vaccinated-only","Control"))
# plot(g1)
# Out:
# Warning message:
# “Ignoring unknown parameters: stat”
# plot without title

# %%
# Create data
data2 <- data.frame(
  name=c("Protected","Unprotected","Vaccinated-only","Control"),  
  value=c(2917, 901, 3509, 5223)
  )

# Barplot
# ggplot(data, aes(x=name, y=value)) + 
#   geom_bar(stat = "identity")

# Plot
g2 <- ggplot(data2, aes(x=name, y=value)) +
    theme_bw() +
    theme(axis.text.x=element_text(face="bold", size=14),
         axis.text.y=element_text(face="bold", size=14),
         axis.title=element_text(size=18)) +
    ylab("Clonotype abundance") +
    xlab("") + 
    geom_col(stat = "identity", fill=sample_colors)

g2 + scale_x_discrete(limits = c("Protected","Unprotected","Vaccinated-only","Control"))
# plot(g1)
# Out:
# Warning message:
# “Ignoring unknown parameters: stat”
# plot without title
