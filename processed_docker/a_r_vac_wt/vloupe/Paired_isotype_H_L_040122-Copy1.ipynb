# %%
library(ggplot2)
library(tidyr)
library(dplyr)
library(reshape2)

# %%
# manual color codes
sample_colors <- c("Unprotected"="deeppink3", "Vaccinated"="steelblue2", "Control"="slategrey")

df <- read.csv("vloupe-paired-isotype.csv")
head(df)

df <- melt(df ,  id.vars = 'paired_isotype', variable.name = 'series')

#create line plot for each column in data frame
ggplot(df, aes(paired_isotype, value)) + theme_bw() + 
        geom_point(aes(colour = series, size=4)) + 
        scale_color_manual(values=sample_colors) +
        theme(axis.text.x=element_text(angle=45, hjust=1, vjust=1)) +
        ylab("Isotype frequency (%)") + xlab("Paired chains") +
        ggtitle("Paired isotype") +
        theme(legend.position="none")
# Out:
#   paired_isotype Control    Vaccinated Unprotected
# 1 IGK + IGHA      0.2550429  1.204416   1.683502
# 2 IGK + IGHD     20.7280315 12.211442  20.763187
# 3 IGK + IGHE      0.0000000  0.000000   0.000000
# 4 IGK + IGHG      0.5796429  1.003680  13.692480
# 5 IGK + IGHM     72.5249246 77.484108  58.922559
# 6 IGL + IGHA      0.0231857  0.133824   0.000000
# plot without title

# %%
# manual color codes
sample_colors <- c("Unprotected"="deeppink3", "Vaccinated"="steelblue2", "Control"="slategrey")

df <- read.csv("vloupe-paired-isotype.csv")
head(df)

df <- melt(df ,  id.vars = 'paired_isotype', variable.name = 'series')

#create line plot for each column in data frame
ggplot(df, aes(paired_isotype, value)) + theme_bw() + 
        geom_point(aes(colour = series, size=4)) + 
        scale_color_manual(values=sample_colors) +
        scale_y_continuous(labels=percent) +
        theme(axis.text.x=element_text(angle=45, hjust=1, vjust=1)) +
        ylab("Isotype frequency (%)") + xlab("Paired chains") +
        ggtitle("Paired isotype") +
        theme(legend.position="none")
# Out:
#   paired_isotype Control    Vaccinated Unprotected
# 1 IGK + IGHA      0.2550429  1.204416   1.683502
# 2 IGK + IGHD     20.7280315 12.211442  20.763187
# 3 IGK + IGHE      0.0000000  0.000000   0.000000
# 4 IGK + IGHG      0.5796429  1.003680  13.692480
# 5 IGK + IGHM     72.5249246 77.484108  58.922559
# 6 IGL + IGHA      0.0231857  0.133824   0.000000
# Error in check_breaks_labels(breaks, labels): object 'percent' not found
# Traceback:
#
# 1. scale_y_continuous(labels = percent)
# 2. continuous_scale(c("y", "ymin", "ymax", "yend", "yintercept",
#  .     "ymin_final", "ymax_final", "lower", "middle", "upper", "y0"),
#  .     "position_c", identity, name = name, breaks = breaks, n.breaks = n.breaks,
#  .     minor_breaks = minor_breaks, labels = labels, limits = limits,
#  .     expand = expand, oob = oob, na.value = na.value, trans = trans,
#  .     guide = guide, position = position, super = ScaleContinuousPosition)
# 3. check_breaks_labels(breaks, labels)
